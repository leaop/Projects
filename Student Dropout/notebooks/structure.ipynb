# %% [markdown]
# # Student Persistence & Dropout Analytics
# ## 01 — INEP 2024 Structure Inspection
#
# ### Objective
#
# Inspect the 2024 Higher Education Census microdata package before defining the analytical model.
#
# This notebook will verify:
#
# - available files;
# - student-level file structure;
# - number of rows and columns;
# - variable names;
# - data types;
# - student status fields;
# - institution, course and municipality identifiers;
# - admission year;
# - modality;
# - financial support variables;
# - possible student identifiers for longitudinal analysis.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
PROJECT_ROOT = Path.cwd().parent
RAW_DIR = PROJECT_ROOT / "data" / "raw"

RAW_DIR

# %%
list(RAW_DIR.iterdir())

# %% [markdown]
# ## Package Contents
#
# The purpose of this section is to identify the files distributed in the official INEP 2024 Higher Education Census package.

# %%
files = sorted(RAW_DIR.rglob("*"))

for file in files:
    if file.is_file():
        print(file.relative_to(PROJECT_ROOT))

# %% [markdown]
# ## Student File Inspection
#
# The student-level file will be identified from the official package documentation before loading the full dataset.

# %% [markdown]
# # Example only — update after inspecting the package
# # student_file = RAW_DIR / "..."
